# %%
def start_quiz():
    # welcome message
    print("!! WELCOME TO KBC !!")
    print("Answer the following questions to win price money!")

    #define the questions, choices, and correct answers
    questions = [
       {
          "questions": "What dose not grow on a tree according to a popular hindi saying?",
          "choices": {
              "a": "Money",
              "b": "Flower",
              "c": "Leaves",
              "d": "Fruits",
          },
          "correct_answer": "a",
          "prize_money": 1000
       },
       # Add more questions here if needed
    ]

    prize_money = 0 

    #loop through the questions
    for q in questions:
        print("\n" + q["questions"])
        for key, value in q["choices"].items():
            print(f"[{key}: {value}]")

        # accept user input 
        user_answer = input("Enter your answer: ").lower()

        # check if the answer is correct
        if user_answer == q["correct_answer"]:
            print(f"correct answer! your prize money is: ₹{q['prize_money']}")
            prize_money += q["prize_money"]
        else:
            print(f"wrong answer! the correct answer was '{q['correct_answer']}'.")

        #display the total prize money
        print("\nquiz over!")
        print(f"your total prize money is: ₹{prize_money}")

  # start the quiz
if __name__ == "__main__":
    start_quiz()
# Out:
# !! WELCOME TO KBC !!
# Answer the following questions to win price money!
#
# What dose not grow on a tree according to a popular hindi saying?
# [a: Money]
# [b: Flower]
# [c: Leaves]
# [d: Fruits]
# Enter your answer:  a
# correct answer! your prize money is: ₹1000
#
# quiz over!
# your total prize money is: ₹1000

# %%
def start_quiz():
    # welcome message
    print("!! WELCOME TO KBC !!")
    print("Answer the following questions to win price money!")

    #define the questions, choices, and correct answers
    questions = [
       {
          "questions": "What is the capital of india?",
          "choices": {
              "a": "mumbai",
              "b": "kolkata",
              "c": "new delhi",
              "d": "chennai",
          },
          "correct_answer": "c",
          "prize_money": 5000
       },
       # Add more questions here if needed
    ]

    prize_money = 1000 

    #loop through the questions
    for q in questions:
        print("\n" + q["questions"])
        for key, value in q["choices"].items():
            print(f"[{key}: {value}]")

        # accept user input 
        user_answer = input("Enter your answer: ").lower()

        # check if the answer is correct
        if user_answer == q["correct_answer"]:
            print(f"correct answer! your prize money is: ₹{q['prize_money']}")
            prize_money += q["prize_money"]
        else:
            print(f"wrong answer! the correct answer was '{q['correct_answer']}'.")

        #display the total prize money
        print("\nquiz over!")
        print(f"your total prize money is: ₹{prize_money}")

  # start the quiz
if __name__ == "__main__":
    start_quiz()
# Out:
# !! WELCOME TO KBC !!
# Answer the following questions to win price money!
#
# What is the capital of india?
# [a: mumbai]
# [b: kolkata]
# [c: new delhi]
# [d: chennai]
# Enter your answer:  c
# correct answer! your prize money is: ₹5000
#
# quiz over!
# your total prize money is: ₹6000

# %%
def start_quiz():
    # welcome message
    print("!! WELCOME TO KBC !!")
    print("Answer the following questions to win price money!")

    #define the questions, choices, and correct answers
    questions = [
       {
          "questions": "how many days in the weeks?",
          "choices": {
              "a": "5",
              "b": "6",
              "c": "7",
              "d": "8",
          },
          "correct_answer": "c",
          "prize_money": 9000
       },
       # Add more questions here if needed
    ]

    prize_money = 6000

    #loop through the questions
    for q in questions:
        print("\n" + q["questions"])
        for key, value in q["choices"].items():
            print(f"[{key}: {value}]")

        # accept user input 
        user_answer = input("Enter your answer: ").lower()

        # check if the answer is correct
        if user_answer == q["correct_answer"]:
            print(f"correct answer! your prize money is: ₹{q['prize_money']}")
            prize_money += q["prize_money"]
        else:
            print(f"wrong answer! the correct answer was '{q['correct_answer']}'.")

        #display the total prize money
        print("\nquiz over!")
        print(f"your total prize money is: ₹{prize_money}")

  # start the quiz
if __name__ == "__main__":
    start_quiz()
# Out:
# !! WELCOME TO KBC !!
# Answer the following questions to win price money!
#
# how many days in the weeks?
# [a: 5]
# [b: 6]
# [c: 7]
# [d: 8]
# Enter your answer:  c
# correct answer! your prize money is: ₹9000
#
# quiz over!
# your total prize money is: ₹15000

# %%
def start_quiz():
    # welcome message
    print("!! WELCOME TO KBC !!")
    print("Answer the following questions to win price money!")

    #define the questions, choices, and correct answers
    questions = [
       {
          "questions": "which softwere is used to create spredsheets?",
          "choices": {
              "a": "MS Word",
              "b": "MS Excel",
              "c": "MS Powerpoint",
              "d": "MS Paint",
          },
          "correct_answer": "b",
          "prize_money": 15000
       },
       # Add more questions here if needed
    ]

    prize_money = 15000 

    #loop through the questions
    for q in questions:
        print("\n" + q["questions"])
        for key, value in q["choices"].items():
            print(f"[{key}: {value}]")

        # accept user input 
        user_answer = input("Enter your answer: ").lower()

        # check if the answer is correct
        if user_answer == q["correct_answer"]:
            print(f"correct answer! your prize money is: ₹{q['prize_money']}")
            prize_money += q["prize_money"]
        else:
            print(f"wrong answer! the correct answer was '{q['correct_answer']}'.")

        #display the total prize money
        print("\nquiz over!")
        print(f"your total prize money is: ₹{prize_money}")

  # start the quiz
if __name__ == "__main__":
    start_quiz()
# Out:
# !! WELCOME TO KBC !!
# Answer the following questions to win price money!
#
# which softwere is used to create spredsheets?
# [a: MS Word]
# [b: MS Excel]
# [c: MS Powerpoint]
# [d: MS Paint]
# Enter your answer:  b
# correct answer! your prize money is: ₹15000
#
# quiz over!
# your total prize money is: ₹30000

# %%
def start_quiz():
    # welcome message
    print("!! WELCOME TO KBC !!")
    print("Answer the following questions to win price money!")

    #define the questions, choices, and correct answers
    questions = [
       {
          "questions": "Which of the following is an operating system?",
          "choices": {
              "a": "Chrome",
              "b": "Windows",
              "c": "Google",
              "d": "Excel",
          },
          "correct_answer": "b",
          "prize_money": 20000
       },
       # Add more questions here if needed
    ]

    prize_money = 30000

    #loop through the questions
    for q in questions:
        print("\n" + q["questions"])
        for key, value in q["choices"].items():
            print(f"[{key}: {value}]")

        # accept user input 
        user_answer = input("Enter your answer: ").lower()

        # check if the answer is correct
        if user_answer == q["correct_answer"]:
            print(f"correct answer! your prize money is: ₹{q['prize_money']}")
            prize_money += q["prize_money"]
        else:
            print(f"wrong answer! the correct answer was '{q['correct_answer']}'.")

        #display the total prize money
        print("\nquiz over!")
        print(f"your total prize money is: ₹{prize_money}")

  # start the quiz
if __name__ == "__main__":
    start_quiz()
# Out:
# !! WELCOME TO KBC !!
# Answer the following questions to win price money!
#
# Which of the following is an operating system?
# [a: Chrome]
# [b: Windows]
# [c: Google]
# [d: Excel]
# Enter your answer:  b
# correct answer! your prize money is: ₹20000
#
# quiz over!
# your total prize money is: ₹50000
